# %%
from pinnfem import EitEnvironment, solve, wrap_to_mesh
from ngsolve.webgui import Draw

# %%
eit_env = EitEnvironment(n_el=8, el_r=0.05)

# %%
eit_env.set_inj_stage(el_plus=0, el_minus=3)

# %%
eit_env.plot_inj_stage()

# %%
eit_env.print_BCs()
# Out:
# Domain BC:
# 	 {'bc': 'default', 'mat': 'air', 'mat_perm': 1, 'pot_val': 0}
#
# Electrodes BC:
#
# 	el_0 {'bc': 'el_mat0', 'mat': 'el_mat', 'mat_perm': 5, 'pot_val': 1}
# 	el_1 {'bc': 'el_mat1', 'mat': 'el_mat', 'mat_perm': 5, 'pot_val': 0}
# 	el_2 {'bc': 'el_mat2', 'mat': 'el_mat', 'mat_perm': 5, 'pot_val': 0}
# 	el_3 {'bc': 'el_mat3', 'mat': 'el_mat', 'mat_perm': 5, 'pot_val': -1}
# 	el_4 {'bc': 'el_mat4', 'mat': 'el_mat', 'mat_perm': 5, 'pot_val': 0}
# 	el_5 {'bc': 'el_mat5', 'mat': 'el_mat', 'mat_perm': 5, 'pot_val': 0}
# 	el_6 {'bc': 'el_mat6', 'mat': 'el_mat', 'mat_perm': 5, 'pot_val': 0}
# 	el_7 {'bc': 'el_mat7', 'mat': 'el_mat', 'mat_perm': 5, 'pot_val': 0}

# %%
# solve and get grid function
refinement = 0.5
gfu = solve(eit_env.domain, eit_env.electrodes, refinement)  # plate3
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.24…
